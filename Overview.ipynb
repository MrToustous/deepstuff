# %%
import pandas as pd
import numpy as np
import json

from utils import load

idx = pd.IndexSlice

# %load_ext autoreload
# %autoreload 2

# %%
DATA_PATH = '/media/toussaint/HDD1/DATA/'

# %%
tracks = pd.read_csv(
    DATA_PATH + 'fma_metadata/tracks.csv', 
    index_col=0, 
    header=[0, 1]
).stack(level=0)
tracks['genres'] = tracks['genres'].map(lambda x: [] if str(x) == 'nan' else json.loads(x))

# %%
tracks.head()
# Out:
#                    active_year_begin active_year_end associated_labels  \
# track_id
# 2        album                   NaN             NaN               NaN
#          artist  2006-01-01 00:00:00             NaN               NaN
#          set                     NaN             NaN               NaN
#          track                   NaN             NaN               NaN
# 3        album                   NaN             NaN               NaN
#
#                                                                bio  bit_rate  \
# track_id
# 2        album                                                 NaN       NaN
#          artist  <p>A Way Of Life, A Collective of Hip-Hop from...       NaN
#          set                                                   NaN       NaN
#          track                                                 NaN  256000.0
# 3        album                                                 NaN       NaN
#
# ...

# %%
tracks['genres'].map(lambda x: len(x)).sum()
# Out:
# 253869

# %%
genres = pd.read_csv(
    DATA_PATH + 'fma_metadata/genres.csv', 
    index_col=0, 
#     header=[0, 1]
)

# %%
genres['#tracks'].sum()
# Out:
# 349160

# %%
genres.sort_values(by='#tracks', ascending=False)
# Out:
#           #tracks  parent                  title  top_level
# genre_id
# 38          38154       0           Experimental         38
# 15          34413       0             Electronic         15
# 12          32923       0                   Rock         12
# 1235        14938       0           Instrumental       1235
# 10          13845       0                    Pop         10
# ...           ...     ...                    ...        ...
# 493             4     651          Western Swing          9
# 173             4      86  N. Indian Traditional          2
# 377             1      19              Deep Funk         14
# 178             0       4                 Be-Bop          4
# 175             0      86              Bollywood          2
#
# [163 rows x 4 columns]

# %%
genres.query('title == "Techno"')
# Out:
#           #tracks  parent   title  top_level
# genre_id
# 181          2140      15  Techno         15

# %%
def get_songs(genre: int = 4):
    mask = tracks.genres.map(lambda x: genre in x, na_action='ignore')
    return tracks[mask.replace(np.NaN, False)].copy()

# %%
techno = get_songs(genre=15)

# %%
techno.shape
# Out:
# (23866, 40)

# %%
techno.sort_index()
# Out:
#                active_year_begin active_year_end associated_labels  bio  \
# track_id
# 236      track               NaN             NaN               NaN  NaN
# 384      track               NaN             NaN               NaN  NaN
# 385      track               NaN             NaN               NaN  NaN
# 386      track               NaN             NaN               NaN  NaN
# 387      track               NaN             NaN               NaN  NaN
# ...                          ...             ...               ...  ...
# 155244   track               NaN             NaN               NaN  NaN
# 155248   track               NaN             NaN               NaN  NaN
# 155275   track               NaN             NaN               NaN  NaN
# 155276   track               NaN             NaN               NaN  NaN
# 155277   track               NaN             NaN               NaN  NaN
#
#                 bit_rate  comments composer         date_created  \
# track_id
# ...

# %%
techno.to_pickle('electro_index.pkl')

# %% [markdown]
# # Extract

# %%
import zipfile

# %%
def id_path(song_id: int = None):
    id_str = str(song_id)
    song_number = id_str
    for i in range(6-len(song_number)):
        song_number = '0' + song_number
    file_number = id_str[:-3]
    for i in range(3-len(file_number)):
        file_number = '0' + file_number
    return file_number + '/' + song_number + '.mp3'

# %%
songs = techno.index.get_level_values(0)

# %%
with zipfile.ZipFile(DATA_PATH + 'fma_large.zip', 'r') as zip_ref:
    for song in songs:
        zip_ref.extract('fma_large/'+id_path(song), 'songs/electro')
#     temp = zip_ref.namelist()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-7a8d6d66c806> in <module>
#       1 with zipfile.ZipFile(DATA_PATH + 'fma_large.zip', 'r') as zip_ref:
#       2     for song in songs:
# ----> 3         zip_ref.extract('fma_large/'+id_path(song), 'songs/electro')
#       4 #     temp = zip_ref.namelist()
#
# ~/miniconda3/envs/deepstuff/lib/python3.7/zipfile.py in extract(self, member, path, pwd)
#    1600             path = os.fspath(path)
#    1601
# -> 1602         return self._extract_member(member, path, pwd)
#    1603
#    1604     def extractall(self, path=None, members=None, pwd=None):
#
# ~/miniconda3/envs/deepstuff/lib/python3.7/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1672         with self.open(member, pwd=pwd) as source, \
#    1673              open(targetpath, "wb") as target:
# ...
